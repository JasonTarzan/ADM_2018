# %% [markdown]
# #### The following graphs and tables are the result of the same analytics which we have done for 2018.We consider the same period for 2017 in order to be comparable. The results show that there isn't significant differences between these two years. The  complete script to analysis 2017 is uploaded as "Anlysis for other years" in the repository.

# %% [markdown]
# # Comparison RQ1

# %% [markdown]
# #### Difference between daily average trips per months

# %% [markdown]
# ![2018%20rq1-1.png](attachment:2018%20rq1-1.png) 2018

# %% [markdown]
# ![2017%20rq1-1.png](attachment:2017%20rq1-1.png) 2017

# %% [markdown]
# #### Difference between average of daily trips per months for each borough

# %% [markdown]
# ![2018%20rq1-2.png](attachment:2018%20rq1-2.png) 2018

# %% [markdown]
# ![2017%20rq1-2.png](attachment:2017%20rq1-2.png) 2017

# %% [markdown]
# # Comparison RQ2

# %% [markdown]
# #### Difference between the number of passengers for  each time slot overall Newyork

# %% [markdown]
# ![2018%20rq2-1.png](attachment:2018%20rq2-1.png) 2018

# %% [markdown]
# ![2017%20rq2-1.png](attachment:2017%20rq2-1.png) 2017

# %% [markdown]
# #### Difference between the number of passengers for  each time slot for every borough

# %% [markdown]
# ![2018%20rq2-2.png](attachment:2018%20rq2-2.png) 2018

# %% [markdown]
# ![2017%20rq2-2.png](attachment:2017%20rq2-2.png) 2017

# %% [markdown]
# # Comparison RQ3

# %% [markdown]
# #### Difference between distributions of trip duration overall Newyork

# %% [markdown]
# ![2018%20rq3-1.png](attachment:2018%20rq3-1.png) 2018

# %% [markdown]
# ![2017%20rq3-1.png](attachment:2017%20rq3-1.png) 2017

# %% [markdown]
# ####  Difference between the number of passengers for  each time slot for each borough

# %% [markdown]
# ![download.png](attachment:download.png) 2018

# %% [markdown]
# ![2017%20rq3-2.png](attachment:2017%20rq3-2.png) 2017

# %% [markdown]
# # Comparison RQ4

# %% [markdown]
# #### Difference between payment type for every borough

# %% [markdown]
# ![2018%20rq4-1.png](attachment:2018%20rq4-1.png) 2018

# %% [markdown]
# ![2017%20rq4-1.png](attachment:2017%20rq4-1.png) 2017

# %% [markdown]
# #### Difference between Chi square test

# %% [markdown]
# ![2018%20rq4-2.png](attachment:2018%20rq4-2.png) 2018

# %% [markdown]
# ![2017%20rq4-2.png](attachment:2017%20rq4-2.png) 2017

# %% [markdown]
# # Comparison RQ5

# %% [markdown]
# #### Difference between correlation of trip distance and trip duration

# %% [markdown]
# ![2018%20rq5-1.png](attachment:2018%20rq5-1.png) 2018

# %% [markdown]
# ![2017%20rq5-1.png](attachment:2017%20rq5-1.png) 2017

# %% [markdown]
# # Comparison CRQ1

# %% [markdown]
# #### Difference between the price per mile for overall Newyork

# %% [markdown]
# ![crq1-1%202018.png](attachment:crq1-1%202018.png) 2018

# %% [markdown]
# ![2017%201.png](attachment:2017%201.png) 2017

# %% [markdown]
# #### Difference between the price per mile for each Borough

# %% [markdown]
# ![crq1-2%202018.png](attachment:crq1-2%202018.png) 2018

# %% [markdown]
# ![2017%202.png](attachment:2017%202.png) 2017

# %% [markdown]
# #### Difference between the  t test for price per mile for each pair of borough

# %% [markdown]
# ![crq1-3%202018.png](attachment:crq1-3%202018.png) 2018

# %% [markdown]
# ![2017%203.PNG](attachment:2017%203.PNG) 2017

# %% [markdown]
# #### Difference between the  price per mile over duration for overall Newyork

# %% [markdown]
# ![crq1-4%202018.png](attachment:crq1-4%202018.png) 2018

# %% [markdown]
# ![2017%204.png](attachment:2017%204.png) 2017

# %% [markdown]
# #### Difference between the  price per mile over duration for each Borough

# %% [markdown]
# ![crq1-5%202018.png](attachment:crq1-5%202018.png) 2018

# %% [markdown]
# ![2017%205.png](attachment:2017%205.png) 2017

# %% [markdown]
# #### Difference between the t test of  price per mile over duration for each pair of Borough

# %% [markdown]
# ![crq1-62018.png](attachment:crq1-62018.png) 2018

# %% [markdown]
# ![2017%206.PNG](attachment:2017%206.PNG) 2017
